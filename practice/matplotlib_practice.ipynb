# %% [markdown]
# ### intro to matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot([1,2,3,4])

# %%
x = [1,2,3,4,5]
y = [11,22,33,44,55]
plt.plot(x,y)
plt.show()

# %%
# 1st method
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x,y)

# %% [markdown]
# ### matplotlib workflow

# %%
#  1. import matplotlib and get it ready
# %matplotlib inline
import matplotlib.pyplot as plt

# 2 prepare data
x = [1, 2, 3, 4, 5]
y = [11, 22, 33, 44, 55]

#  3. set up plot
fig, ax = plt.subplots(figsize = (5,5) )

#  4. plot data
ax.plot(x, y)

# 5.  customize plot
ax.set(title = 'sample project', xlabel= 'x-axis', ylabel= 'y-axis')

#  6.  save the plot
fig.savefig('./sample-plot.png')

# %% [markdown]
# ### making figures with numpy array

# %%
import numpy as np

# %%
x = np.linspace(0,10,100)

# %%
#  line plot
fix, ax = plt.subplots(figsize = (5,5) )
ax.plot(x, x**2)

# %%
#  scatter plot
fig, ax = plt.subplots(figsize = (5,5))
ax.scatter(x, np.exp(x))

# %%
# one more scatter
fig, ax = plt.subplots(figsize = (5,5))
ax.scatter(x, np.cos(x))

# %%
# making a plot from dictionary
nut_butter_prices = {"Almond butter": 10,
                    "Peanut butter":8,
                    "Cashew butter": 12}

fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values())
ax.set(title="Nut butter prices", xlabel= "Butters", ylabel="Prices $");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()),list(nut_butter_prices.values()))
ax.set(title="Nut butter prices", xlabel= "Prices $", ylabel="Butters");

# %% [markdown]
# ### hist

# %%
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### plotting from pandas dataframe

# %%
import pandas as pd

# %%
# make a dataframe

# %%
car_sales = pd.read_csv("car_sales.csv")

# %%
ts = pd.Series(np.random.randn(1000),
              index = pd.date_range("1/1/2020", periods=1000))

# %%
ts.tail()
# Out:
# 2022-09-22    0.101385
# 2022-09-23   -1.626762
# 2022-09-24    0.728612
# 2022-09-25   -2.430730
# 2022-09-26   -0.190469
# Freq: D, dtype: float64

# %%
ts = ts.cumsum()

# %%
ts.tail()
# Out:
# 2022-09-22    22.709633
# 2022-09-23    21.082871
# 2022-09-24    21.811483
# 2022-09-25    19.380753
# 2022-09-26    19.190285
# Freq: D, dtype: float64

# %%
ts.plot()
# Out:
# <Axes: >

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'] = car_sales['Price'].replace('[\$,]', '', regex=True).astype(float).astype(int)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\INTEL I5\AppData\Local\Temp\ipykernel_9060\1193216461.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales['Price'] = car_sales['Price'].replace('[\$,]', '', regex=True).astype(float).astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
 car_sales["Sales Date"] = pd.date_range("1/1/2020", periods=10)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales['Total Sales'] = car_sales['Price'].cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x = "Sales Date", y = "Total Sales")
# Out:
# <Axes: xlabel='Sales Date'>

# %%
car_sales.plot(x = "Odometer (KM)", y = "Price", kind = 'scatter')
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
x = np.random.rand(10,4)
x

df = pd.DataFrame(x, columns= ['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.309229  0.491273  0.010643  0.726677
# 1  0.316881  0.202503  0.385231  0.450170
# 2  0.528311  0.424555  0.921730  0.683656
# 3  0.812554  0.492609  0.978093  0.090494
# 4  0.447371  0.242217  0.370019  0.245675
# 5  0.877784  0.726356  0.260185  0.345406
# 6  0.761558  0.490388  0.403474  0.090462
# 7  0.174208  0.215068  0.058248  0.214770
# 8  0.529755  0.196171  0.303487  0.756615
# 9  0.796166  0.806685  0.532353  0.932939

# %%
df.plot.barh()
# Out:
# <Axes: >

# %%
car_sales.plot(x = 'Make', y = "Odometer (KM)", kind = 'barh')
# Out:
# <Axes: ylabel='Make'>

# %%
heart_disease = pd.read_csv("heart-disease.csv")

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_diesease.age.plot.barh()
# Out:
# <Axes: >

# %%
heart_diesease.plot.hist(figsize = (10, 30) ,subplots = True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#       dtype=object)

# %%
over_50 = heart_diesease[heart_diesease['age'] > 50]

# %%
over_50.head(0)
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %%
over_50.plot(kind = 'scatter', x = 'age', y = 'chol', c = 'target')
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
# oooo method

# %%
fig, ax = plt.subplots(figsize = (10,6))
over_50.plot(kind = 'scatter', x = 'age', y = 'chol', c = 'target', ax = ax)
# ax.set_xlim([45,100])
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
fig, ax = plt.subplots(figsize = (10, 6))

scatter = ax.scatter(x = over_50['age'],
                    y = over_50['chol'],
                    c = over_50['target'])

ax.set(title='HEart disease and cholestrol levels', xlabel= 'age', ylabel='cholestrol');

# addng legend
ax.legend(*scatter.legend_elements(), title = 'target');

# add a horizontal line
ax.axhline(over_50['chol'].mean(), linestyle = '--')

# %%
fig , (ax0, ax1) = plt.subplots(nrows = 2, ncols = 1, figsize = (5,5))

scatter = ax0.scatter(x = over_50['age'],
                      y = over_50['chol'],
                      c = over_50['target']);

ax0.set(title = 'heart disease vs cholestrol levels', xlabel='age', ylabel='cholestrol')
# addng legend
ax0.legend(*scatter.legend_elements(), title = 'target');

# add a horizontal line
ax0.axhline(over_50['chol'].mean(), linestyle = '--')

scatter = ax1.scatter(x = over_50['age'],
                      y = over_50['thalach'],
                      c = over_50['target']);

ax1.set(title = 'heart disease vs thalach levels', xlabel='age', ylabel='thalach')
# addng legend
ax1.legend(*scatter.legend_elements(), title = 'target');

# add a horizontal line
ax1.axhline(over_50['thalach'].mean(), linestyle = '--')

fig.suptitle("Heart disease analysis", fontsize = 16, fontweight = "bold");

# %% [markdown]
# customizing my plot baby

# %%
car_sales['Price'].plot()
# Out:
# <Axes: >

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-whitegrid')
